# %%
import pandas as pd
import os
import numpy as np 
import prince
from scipy import stats
from ydata_profiling import ProfileReport

# %%
base_dir = os.getcwd()
data_dir = os.path.join(base_dir, '../..', 'data')
filepath = os.path.join(data_dir, 'cleaned/final_batters_df.csv')

batters = pd.read_csv(filepath)
profile = ProfileReport(batters,
                        title = 'Batters: Exploratory Data Analysis',
                        html = {'style':{'full_width':True}},
                        minimal = False)
profile.to_file("batters_eda.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
base_dir = os.getcwd()
data_dir = os.path.join(base_dir, '../..', 'data')
filepath = os.path.join(data_dir, 'cleaned/final_pitchers_df.csv')

pitchers = pd.read_csv(filepath)
profile2 = ProfileReport(batters,
                        title = 'Pitchers: Exploratory Data Analysis',
                        html = {'style':{'full_width':True}},
                        minimal = False)
profile2.to_file("pitchers_eda.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
